# %%
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
import matplotlib.pyplot as plt
from obspy.geodetics.base import gps2dist_azimuth,kilometer2degrees
from obspy.taup import TauPyModel
from obspy.signal.rotate import rotate_ne_rt
from matplotlib.ticker import MultipleLocator
from obspy.signal.filter import envelope
from obspy import read, read_inventory, Trace
import numpy as np
import os
import warnings
warnings.filterwarnings("ignore")
model = TauPyModel(model="iasp91")
client = Client("IRIS")
plt.rcParams['font.sans-serif']='Times New Roman'

# %%
starttime = UTCDateTime("2010-10-01")
endtime = UTCDateTime("2015-10-01")
cat = client.get_events(starttime=starttime, endtime=endtime,
                        minmagnitude=6,latitude =41.115,longitude=43.8036,
                        minradius=90,maxradius=140)
print(cat)
# Out:
# 390 Event(s) in Catalog:
# 2015-09-28T15:28:05.000000Z | -23.800,  -66.600 | 6.0 mwc
# 2015-09-26T02:51:18.830000Z | -30.815,  -71.322 | 6.3 mww
# ...
# 2010-11-03T11:18:17.330000Z |  -4.649, +134.106 | 6.0 MW
# 2010-10-21T17:53:13.770000Z | +24.788, -109.174 | 6.7 MW
# To see all events call 'print(CatalogObject.__str__(print_all=True))'

# %%
freqmin=0.04
freqmax=0.125
FIG_DIR=f'/Volumes/home/Research/Progress/01_GO_record_plot_SKS_{freqmin}-{freqmax}'
if not os.path.isdir(FIG_DIR):
    os.mkdir(FIG_DIR)
    
    
Rphase = ['S','Sdiff', 'SS' ,'SSS' ,'SSSS' ,'SKS' ,'SKKS' ,'SKKKS' ,'ScP' ,'SP' ,'PS' ,'PcS','SKP','PKS' ]
Tphase = ['S','Sdiff','SS','SSS','SSSS','ScS']
phaselist = set(Rphase + Tphase)
phasecolor = {'SKS':'lightcoral', 'SKKS':'lightblue','SKKKS':'lightgreen'}
EVILSTA=['SEAG','KZRT','BATM','BGD','DGRG','TRLG','CHVG','LGD','DDFL']
GOODSTA=['ONI','AKH']

mmm = 10**-4
exg = 2
arr_size=25

# %%
def SNRwindow(arr_t):
    signalbegin = arr_t -5
    signalend   = arr_t +25
    noiseend    = arr_t -20 
    noisebegin  = arr_t -20-60
    return signalbegin,signalend,noiseend,noisebegin

# %%
for cata in cat:
    eq_time = cata.origins[0].time
    print(eq_time)
    eq_lon = cata.origins[0].longitude
    eq_lat = cata.origins[0].latitude
    depth  = cata.origins[0].depth/1000
    mag    = cata.magnitudes[0].mag
    mag_type = cata.magnitudes[0].magnitude_type
    
    inv = client.get_stations(network="GO", station='*', channel="*",
                                    starttime=eq_time,endtime=eq_time+30*60)
    inv1 = client.get_stations(network="IU", station='GNI', channel="*",
                                    starttime=eq_time,endtime=eq_time+30*60)
    inv2 = client.get_stations(network="II", station='KIV', channel="*",
                                    starttime=eq_time,endtime=eq_time+30*60)
    inv = inv + inv1 + inv2   

    
    deglist = [] ; STAlist = []; BAZlist = []
    for net_i in inv:
        NET=net_i.code   
        for sta_i in net_i:
            STA = sta_i.code
            if STA not in EVILSTA:
                st_lat = sta_i.latitude
                st_lon = sta_i.longitude

                dist,azi,baz = gps2dist_azimuth(eq_lat,eq_lon,st_lat,st_lon)
                dist = dist/1000
                deg = kilometer2degrees(dist)

                deglist.append(deg)
                STAlist.append(STA)
                BAZlist.append(baz)
##=============calculate traval time=====================
    min_arrivals = model.get_travel_times(source_depth_in_km=depth,distance_in_degree=min(deglist),phase_list=phaselist)
    for arr in min_arrivals:
        name=arr.phase.name
        if arr.time <1810:
            locals()['min_arr_%s' % (name)]= arr.time
    max_arrivals = model.get_travel_times(source_depth_in_km=depth,distance_in_degree=max(deglist),phase_list=phaselist)
    for arr in max_arrivals:
        name=arr.phase.name
        if arr.time <1810:       
            locals()['max_arr_%s' % (name)]= arr.time
##=============plot traval time curves====================  
    plt.figure(1,figsize=(10,12))
    ax1 = plt.subplot(121)
    ax2 = plt.subplot(122)
    for phase in Rphase:
        if phase == 'SKS' or phase == 'SKKS' or phase == 'SKKKS':
            ph_color = phasecolor[phase]
        else: ph_color = 'grey'
        try:
            min_arr_t= locals()['min_arr_%s' % (phase)]
            max_arr_t= locals()['max_arr_%s' % (phase)]
            if  min_arr_SKS-20 < min_arr_t < max_arr_SKKKS+20:
                ax1.plot([min_arr_t,max_arr_t],[min(deglist)-0.1,max(deglist)+0.1],ls='--',color=ph_color) 
                ax1.text(min_arr_t,max(deglist)+0.15,phase,c='k',fontsize=8,ma='left',
                         bbox=dict(boxstyle="round",ec=ph_color,fc='white'))
        except KeyError: continue
    for phase in Tphase:
        try:
            min_arr_t= locals()['min_arr_%s' % (phase)]
            max_arr_t= locals()['max_arr_%s' % (phase)]
            if min_arr_SKS -20 <min_arr_t < max_arr_SKKKS+20:
                ax2.plot([min_arr_t,max_arr_t],[min(deglist)-0.1,max(deglist)+0.1],ls='--',alpha=0.4) 
                ax2.text(min_arr_t,max(deglist)+0.15,phase,c='k',fontsize=8,ma='left',
                         bbox=dict(boxstyle="round",ec=(1., 0.5, 0.5),fc='white'))
        except KeyError: continue
##========================================================
    i = 0 
    for net_i in inv:
        NET=net_i.code
        if NET == 'GO':
            preflit = [0.001,0.005,45,50]
        elif NET == 'II' or NET == 'IU':
            preflit = [0.001,0.005,9,10]
        for sta_i in net_i:
            STA = sta_i.code
            if STA in STAlist:
                print(i,STA)
                baz = BAZlist[i]
                deg = deglist[i]
                i+=1
                try:
                    ori_st = client.get_waveforms(NET, STA,'*','*',eq_time+min_arr_SKS-100,eq_time+max_arr_SKKKS+25,attach_response=True)
                    st = ori_st.copy()
                    st.merge(fill_value=0)
                    st.remove_response(pre_filt = preflit, output="DISP")
                    st.detrend('linear')
                    st.detrend('demean')
                    st.taper(0.05,type='cosine')
                    st.filter('bandpass',freqmin=freqmin,freqmax=freqmax,corners=4,zerophase=True)
                    dt = 1 / st[0].stats.sampling_rate
                    if NET == 'GO':
                        HHE = st.select(component='E')[0].data
                        HHN = st.select(component='N')[0].data
                        HHR,HHT = rotate_ne_rt(HHN,HHE,baz)
                    elif NET == 'IU' or NET == 'II' :
                        HH2 = st.select(location='00', channel='BH2')[0].data
                        HH1 = st.select(location='00', channel='BH1')[0].data
                        HHR,HHT = rotate_ne_rt(HH1,HH2,baz)

    ##==========================calculate SNR =========================       
                    arrivals = model.get_travel_times(source_depth_in_km=depth,distance_in_degree=deg,phase_list=['SKS','SKKS'])
                    arr_SKS = arrivals[0].time
                    arr_SKKS = arrivals[1].time
                
                    SKS_signalbegin,SKS_signalend,SKS_noiseend,SKS_noisebegin = SNRwindow(arr_SKS)
                    ax1.text(SKS_signalbegin,deg,'|',color='r',fontsize=15,fontweight='bold')
                    ax1.text(SKS_signalend,deg,'|',color='r',fontsize=15,fontweight='bold')
                    temp_tr = Trace(data=HHR)
                    temp_tr.stats.delta = dt
                    temp_tr.stats.starttime = st[0].stats.starttime

                    SKS_noise = temp_tr.slice(starttime=eq_time+SKS_noisebegin,endtime=eq_time+SKS_noiseend)
                    SKS_signal = temp_tr.slice(starttime=eq_time+SKS_signalbegin ,endtime = eq_time+SKS_signalend)
                    SKS_signal_envelope = envelope(SKS_signal.data)
                    SKS_noise_envelope = envelope(SKS_noise.data)

                    SKS_cal_signal = sum(SKS_signal_envelope**2)
                    SKS_cal_noise = sum(SKS_noise_envelope**2)

                    SKS_SNR = int(SKS_cal_signal * 2 / SKS_cal_noise)

                    SKKS_signalbegin,SKKS_signalend,SKKS_noiseend,SKKS_noisebegin = SNRwindow(arr_SKKS)

                    SKKS_signal = temp_tr.slice(starttime=eq_time+SKKS_signalbegin ,endtime = eq_time+SKKS_signalend)
                    ax1.text(SKKS_signalbegin,deg,'|',color='r',fontsize=15,fontweight='bold')
                    ax1.text(SKKS_signalend,deg,'|',color='r',fontsize=15,fontweight='bold')
                    SKKS_signal_envelope = envelope(SKKS_signal.data)
                    SKKS_cal_signal = sum(SKKS_signal_envelope**2)
                    SKKS_SNR = int(SKKS_cal_signal * 2 / SKS_cal_noise)
    ##================================================================= 

                    times = st[0].times(reftime=eq_time)
                    plot_HHR = HHR/ mmm
                    plot_HHT = HHT/ mmm

                    if STA in GOODSTA:
                        color = 'k'
                    else : color='k'

                    
                    ax1.set_title('R component')
                    ax1.set_xlim(times[0],times[-1])
                    ax1.set_ylim(min(deglist)-0.2,max(deglist)+0.2)
                    ax1.set_xlabel('Time after origin time (s)',fontsize=12)
                    ax1.set_ylabel('Distence (degree)',fontsize=12)
                    ax1.text(SKS_noisebegin,deg,'|',color='grey',fontsize=15,fontweight='bold')
                    ax1.text(SKS_noiseend,deg,'|',color='grey',fontsize=15,fontweight='bold')
                    ax1.text(times[-1]+3,deg,f'{SKS_SNR},{SKKS_SNR}',fontsize=11,color=color)
                    ax1.plot(times, plot_HHR*exg+deg,c=color,lw=1.5)
                    
                    
                    ax2.set_title('T component')
                    ax2.set_xlim(times[0],times[-1])
                    ax2.set_ylim(min(deglist)-0.2,max(deglist)+0.2)
                    ax2.set_xlabel('Time after origin time (s)',fontsize=12)
                    ax2.text(times[-1]+5,deg,f'{STA}',fontsize=12,color=color)
                    ax2.plot(times, plot_HHT*exg+deg, c=color,lw=1.5)
                    plt.suptitle(f'{eq_time}\n lat:{eq_lat} lon:{eq_lon} dep:{depth}km  {mag}{mag_type}\nbp:{freqmin}-{freqmax}Hz', 
                             fontsize=20)
                except Exception as e  : print(f'{NET} {STA} no data'); continue
    ax1.text(times[0]+5,max(deglist)+0.15,f'Amp: {mmm}',fontsize=8)
    ax2.text(times[0]+5,max(deglist)+0.15,f'Amp: {mmm}',fontsize=8)
    plt.savefig(f'{FIG_DIR}/{eq_time}.png',dpi=200,facecolor='white')
    plt.close()

######==============變數刪除================    
    for arr in min_arrivals:
        name=arr.phase.name
        var = 'min_arr_'+name
        if var in locals():
            del locals()['min_arr_%s' % (name)]
    for arr in max_arrivals:
        name=arr.phase.name
        var = 'max_arr_'+name
        if var in locals():
            del locals()['max_arr_%s' % (name)]
# Out:
# 2015-09-28T15:28:05.000000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-26T02:51:18.830000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-22T07:13:00.520000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-22T07:13:00.000000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-21T17:40:00.060000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-21T05:39:34.910000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-21T05:39:34.000000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-19T12:52:20.920000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-19T12:52:20.000000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-19T05:06:47.500000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-18T09:10:44.730000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-17T04:10:27.780000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-17T04:10:27.000000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-17T03:55:15.430000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-17T01:41:05.870000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-16T23:18:41.850000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-16T23:16:09.440000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-16T23:03:56.560000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-16T22:59:15.000000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-16T22:54:32.860000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-16T14:03:22.110000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-13T08:14:08.560000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-09-07T08:46:09.050000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-08-15T07:47:07.590000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-08-12T18:49:24.420000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-08-10T04:12:14.660000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-07-27T21:41:20.760000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-07-18T02:27:32.760000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-07-16T15:16:32.980000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-07-10T04:12:42.920000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-06-30T03:39:28.010000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-06-21T21:28:16.290000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-06-20T02:10:07.650000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-06-17T12:51:35.660000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-06-16T06:17:00.060000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-06-12T11:07:06.880000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-06-10T13:52:08.660000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-05-30T17:18:39.190000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-05-22T23:59:33.410000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-05-22T21:45:20.190000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-05-20T22:48:54.650000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-05-07T07:10:23.020000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-05-05T01:44:04.220000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-05-01T08:06:53.710000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-05-01T08:06:05.600000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-04-30T10:45:05.250000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-04-28T16:39:39.480000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-04-22T22:57:16.900000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-04-17T15:52:53.280000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-04-07T00:46:21.160000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-03-31T12:18:25.170000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-03-30T08:48:26.120000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-03-30T08:18:01.980000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-03-30T07:56:52.730000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-03-29T23:48:31.000000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-03-23T04:51:37.830000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-03-22T05:46:22.290000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-03-18T18:27:28.660000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-03-10T20:55:44.520000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-02-22T14:23:13.660000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-02-19T13:18:33.120000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-02-18T09:32:29.960000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-02-16T22:00:54.320000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-02-11T18:57:20.460000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-02-02T10:49:48.440000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-02-02T08:25:51.300000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-01-30T17:57:59.180000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-01-28T02:43:19.570000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-01-23T03:47:27.530000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2015-01-07T05:07:06.240000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2014-12-30T21:17:22.000000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2014-12-26T23:52:30.900000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2014-12-26T23:52:15.160000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2014-12-08T08:54:52.520000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2014-12-07T21:16:31.980000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2014-12-07T01:22:02.180000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2014-12-06T22:05:10.730000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2014-12-06T17:21:49.020000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2014-11-13T10:24:18.390000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2014-11-07T03:33:55.020000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2014-11-02T17:17:04.560000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-11-01T18:57:22.350000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-10-28T03:15:38.030000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-10-14T03:51:37.110000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-10-08T02:40:52.930000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-10-01T03:38:53.300000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-09-25T09:13:52.720000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-09-24T11:16:13.260000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-09-06T19:22:57.390000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-08-24T23:21:43.400000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-08-24T23:21:41.700000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-08-24T10:20:45.600000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-08-23T22:32:23.320000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-08-06T11:45:28.700000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-08-06T11:45:22.680000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-08-03T00:22:01.730000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-07-29T13:27:47.100000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-07-29T13:27:40.080000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-07-29T10:46:13.600000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-07-21T14:54:41.000000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-07-19T12:27:16.000000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-07-19T12:27:10.040000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-07-08T12:56:30.900000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-07-08T12:56:25.920000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-07-07T11:23:54.780000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-07-04T15:00:27.860000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-07-02T05:53:34.200000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-07-02T05:53:29.200000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-06-29T17:15:12.130000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-06-29T15:52:28.450000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-06-29T14:32:49.770000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-06-29T07:52:56.840000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-06-19T10:17:58.030000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-05-31T11:53:46.850000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-05-15T08:16:36.160000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-05-14T20:56:16.330000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-05-13T06:35:24.530000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-05-10T07:36:00.600000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-05-09T10:32:19.740000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-05-08T17:00:15.920000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-05-07T04:20:39.080000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-05-04T09:25:15.290000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-05-04T09:15:52.240000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-05-01T06:36:36.820000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-20T00:15:59.560000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-19T13:28:00.720000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-19T01:04:04.680000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-18T14:27:24.690000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-18T04:13:13.530000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-17T15:06:50.220000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-15T03:57:01.840000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-13T13:25:04.760000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-13T12:36:19.050000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-12T20:14:38.580000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-12T05:24:27.280000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-11T20:29:13.610000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-11T08:16:49.270000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-11T07:07:22.810000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-11T00:01:43.940000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-10T23:27:45.030000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-04T11:40:33.190000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# 2014-04-04T01:37:51.480000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-04-03T05:26:13.640000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-04-03T02:43:14.260000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-04-03T01:58:29.040000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-04-02T16:13:26.700000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-04-01T23:57:56.540000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-04-01T23:46:47.380000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-03-27T03:49:44.480000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-03-23T18:20:01.190000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-03-22T12:59:57.000000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-03-17T05:11:33.400000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-03-16T21:16:28.980000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-03-15T23:51:32.300000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-03-15T08:59:20.160000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-03-11T22:03:12.450000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-03-11T02:44:06.280000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-03-10T17:33:29.920000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-03-10T05:18:13.590000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-03-05T09:56:58.660000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-03-02T22:17:17.210000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-03-02T09:37:54.760000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# 2014-02-07T08:40:13.500000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-02-01T03:58:45.070000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# 2014-01-21T01:29:11.890000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2014-01-13T04:01:04.530000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2014-01-01T16:03:29.770000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-12-01T01:24:15.720000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-11-25T06:27:34.680000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-11-23T07:48:32.020000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-11-17T09:04:56.260000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-11-16T03:34:34.790000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-11-13T23:45:48.200000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-10-31T23:03:58.620000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-10-30T02:51:49.440000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-10-29T10:37:56.300000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-10-24T19:25:10.300000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-10-19T17:54:57.220000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-10-16T10:31:00.990000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-10-12T02:10:28.910000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-09-25T16:42:43.180000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-09-11T12:44:14.520000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-09-07T00:13:29.910000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-09-01T11:52:32.120000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-08-21T12:38:29.510000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-08-13T15:43:15.910000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-08-12T09:49:31.920000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-08-12T00:53:44.440000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-08-01T20:01:42.990000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-07-26T21:33:00.060000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-07-26T07:07:17.330000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-07-17T02:37:43.740000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-07-15T14:03:41.730000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-07-07T20:30:07.380000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-07-07T18:35:31.380000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-07-04T17:15:57.680000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-06-15T17:34:29.170000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-06-05T04:47:27.260000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-05-11T20:46:57.260000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-04-23T23:14:43.060000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-04-22T01:16:32.560000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-04-20T04:51:12.270000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-04-16T22:55:27.360000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-04-14T01:32:24.640000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-04-13T22:49:49.200000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-04-06T04:42:36.190000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-03-25T23:02:12.520000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-03-24T08:13:45.160000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-03-19T03:29:02.700000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-03-10T22:51:51.130000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-22T12:01:58.670000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# 2 ONI
# GO ONI no data
# 3 TBLG
# GO TBLG no data
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-10T18:39:36.130000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-09T21:02:22.690000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-09T14:16:06.960000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-08T15:26:38.770000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-08T11:12:13.280000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-07T18:59:16.580000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-07T00:30:12.810000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-06T11:53:54.820000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-06T06:35:22.030000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-06T01:54:15.040000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-06T01:23:23.580000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-06T01:12:26.380000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-06T00:07:21.730000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-01T22:18:36.330000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-01T22:16:37.420000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-02-01T05:36:42.100000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-01-31T03:33:45.270000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-01-30T23:03:47.710000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2013-01-30T20:15:43.390000Z
# 0 AKH
# GO AKH no data
# 1 GUDG
# GO GUDG no data
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2012-12-21T22:28:08.080000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# IU GNI no data
# 5 KIV
# II KIV no data
# 2012-12-15T19:30:03.140000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2012-12-14T10:36:01.840000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2012-12-10T16:53:09.490000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2012-12-02T00:54:23.210000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2012-11-29T11:10:25.720000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2012-11-19T09:44:35.480000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# GO ONI no data
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2012-11-15T09:20:21.450000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2012-11-14T19:02:05.690000Z
# 0 AKH
# 1 GUDG
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2012-11-13T04:31:30.980000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 ONI
# 3 TBLG
# 4 GNI
# 5 KIV
# II KIV no data
# 2012-11-11T22:14:59.050000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 TBLG
# 3 GNI
# 4 KIV
# II KIV no data
# 2012-11-10T14:57:50.210000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 TBLG
# 3 GNI
# 4 KIV
# II KIV no data
# 2012-11-07T16:35:49.310000Z
# 0 AKH
# 1 GUDG
# GO GUDG no data
# 2 TBLG
# 3 GNI
# 4 KIV
# II KIV no data
# 2012-10-24T00:45:33.800000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-10-20T23:00:32.930000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-10-12T00:31:31.370000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-10-09T12:32:08.820000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-10-08T06:26:23.590000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-09-30T16:31:34.070000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-09-25T23:45:24.370000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-09-08T10:51:45.590000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-09-05T14:42:07.730000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-09-05T13:09:10.400000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-08-27T04:37:19.650000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-08-19T22:41:50.220000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-08-02T09:56:43.210000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-08-02T09:38:31.250000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-07-28T20:03:59.070000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-07-25T11:20:27.880000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-07-06T02:28:22.550000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-06-07T16:03:18.520000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-06-07T04:05:04.070000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-06-04T03:15:24.590000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-06-04T00:45:16.380000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-06-02T07:52:54.600000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-05-28T05:07:23.520000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-05-23T22:59:54.180000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-05-18T02:00:43.710000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-05-14T10:00:39.800000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-05-01T22:43:35.030000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-04-21T01:25:14.110000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-04-21T01:16:53.670000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-04-17T19:03:57.120000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-04-17T07:13:49.880000Z
# 0 AKH
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-04-17T03:50:15.280000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-04-14T22:05:26.550000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-04-14T10:56:18.310000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-04-12T07:15:49.170000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-04-12T07:06:01.370000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-04-11T22:55:10.820000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-04-11T22:41:46.780000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-04-06T16:15:56.200000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-04-02T17:36:42.500000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-03-26T18:12:53.010000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-03-25T22:37:06.560000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-03-21T22:15:05.590000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-03-20T18:02:47.620000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-03-20T17:56:19.060000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-03-14T21:13:10.250000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-03-09T07:09:53.320000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-03-05T07:46:09.330000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-03-03T12:19:55.730000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-02-14T08:19:57.460000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-02-10T01:47:33.110000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-02-05T16:40:41.110000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-02-05T00:15:40.050000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-02-03T03:46:23.550000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-02-02T13:34:41.010000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-01-30T05:10:59.460000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-01-24T00:52:04.760000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-01-23T16:04:53.300000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-01-22T05:53:43.130000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-01-21T18:47:13.480000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-01-15T14:21:34.410000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-01-15T13:40:21.400000Z
# 0 AKH
# 1 TBLG
# 2 GNI
# 3 KIV
# II KIV no data
# 2012-01-09T04:07:15.020000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-12-26T04:48:06.170000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-12-14T05:04:57.810000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-12-11T09:54:56.480000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-12-11T01:47:25.400000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-12-07T22:23:07.780000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-11-28T12:26:47.640000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-11-22T18:48:16.290000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-11-17T01:57:04.790000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-11-07T22:35:25.320000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-11-01T12:32:03.770000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-10-28T18:54:34.750000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-10-27T00:15:24.420000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-10-18T05:05:06.650000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-10-14T03:35:15.080000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-09-22T23:07:03.910000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-09-15T19:31:03.160000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-09-09T19:26:02.160000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-09-05T09:52:00.820000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-09-03T22:55:35.760000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-09-03T04:48:58.780000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-09-02T13:47:10.700000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-09-01T06:14:39.900000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-08-24T23:06:18.750000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-08-24T17:46:11.560000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-08-20T18:19:24.610000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-08-20T17:13:06.480000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-08-20T16:55:04.090000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-08-19T03:54:26.500000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-07-31T23:38:58.090000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-07-31T14:34:49.280000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-07-29T07:42:22.560000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-07-26T17:44:21.510000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-07-25T00:50:50.560000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-07-20T22:05:00.620000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-07-16T00:26:12.360000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-07-15T13:26:02.850000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-06-26T12:16:39.550000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-06-24T06:33:05.010000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-06-21T02:04:16.940000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-06-20T16:36:00.870000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-06-16T00:03:37.600000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-06-05T11:51:13.630000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-06-01T12:55:21.010000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-05-15T18:37:10.890000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-05-13T22:47:55.340000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-05-10T08:55:12.500000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-04-30T08:19:16.720000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-04-23T04:16:55.310000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-04-07T13:11:23.430000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-04-03T14:07:08.980000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-03-31T00:11:58.880000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-03-26T22:49:43.300000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-03-17T02:48:01.880000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-03-09T21:24:52.110000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-03-07T00:09:38.150000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-03-06T14:32:42.100000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-03-06T14:32:36.940000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-03-06T12:31:58.500000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-02-25T13:07:26.980000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-02-21T10:57:51.760000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-02-14T03:40:09.250000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-02-12T01:17:00.710000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-02-11T23:39:21.240000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-02-11T20:05:28.880000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-02-07T19:53:42.860000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-01-13T16:43:10.750000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-01-13T16:16:42.660000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-01-09T17:21:53.960000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-01-09T10:03:43.620000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-01-05T06:46:15.380000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-01-02T20:20:18.170000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2011-01-01T09:56:58.460000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2010-12-29T06:54:22.310000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2010-12-28T08:34:17.100000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2010-12-25T13:16:38.180000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2010-12-15T11:29:30.930000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2010-12-13T01:14:42.830000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# IU GNI no data
# 3 KIV
# II KIV no data
# 2010-12-08T05:24:35.150000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# IU GNI no data
# 3 KIV
# II KIV no data
# 2010-12-02T03:12:09.410000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2010-12-01T16:01:27.140000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2010-11-23T09:01:07.160000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2010-11-10T04:05:25.140000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2010-11-03T11:18:17.330000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
# 2010-10-21T17:53:13.770000Z
# 0 AKH
# GO AKH no data
# 1 TBLG
# GO TBLG no data
# 2 GNI
# 3 KIV
# II KIV no data
